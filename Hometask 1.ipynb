# %%
import csv
import sys
maxInt = sys.maxsize
while True:
    # decrease the maxInt value by factor 10
    # as long as the OverflowError occurs.
    try:
        csv.field_size_limit(maxInt)
        break
    except OverflowError:
        maxInt = int(maxInt/10)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# 1. Посмотрите видео Дэвида Бизли про всроенные инструменты Python
# 2. Попробуйте используя встроенные инструменты Python проанализировать таблицу из файла "Vacancy.csv"
# 3. Попробуйте ответить на вопросы:
# Сколько вакансий, которые вам нравятся?
# Насколько свежие эти вакансии?
# Сколько вакансий с позициями на которых вы работаете?
# Сколько вакансий для аналатика данных?
# Сколько вакансий для аналитика данных с использованием Python?

# В задании важно не использовать pandas и numpy, а встроенные инструменты python
# Counter, CSV, defaultdict, sorted

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
vac = list(csv.DictReader(open('vacancy.csv', encoding='utf-8')))

# %%
vac[0]
# Out:
# OrderedDict([('id', '383479'),
#              ('created_at', '2021-03-14 09:39:21.854462'),
#              ('updated_at', '2021-03-14 09:39:21.854584'),
#              ('vacid', '1474941'),
#              ('vactitle', 'Senior java-разработчик (в команду Онбординга)'),
#              ('vacdescription',
#               ' Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка. Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.'),
#              ('vacdate', '2021-03-15'),
#              ('vacstatus', 'new'),
#              ('vaclink',
#               'https://my.sbertalents.ru/#/job-requisition/1474941'),
#              ('vachtml',
#               '{"title": "Senior java-\\u0440\\u0430\\u0437\\u0440\\u0430\\u0431\\u043e\\u0442\\u0447\\u0438\\u043a (\\u0432 \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0443 \\u041e\\u043d\\u0431\\u043e\\u0440\\u0434\\u0438\\u043d\\u0433\\u0430)", "footer": "<p class=\\"1\\">&nbsp;</p><p class=\\"1\\"><strong><span style=\\"font-size:14px\\"><span lang=\\"ru\\"><span style=\\"background:white\\">\\u0420\\u0430\\u0431\\u043e\\u0442\\u0430 \\u0443 \\u043d\\u0430\\u0441 &mdash; \\u044d\\u0442\\u043e:</span></span></span></strong></p><ul><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0430 \\u043f\\u0440\\u043e\\u0444\\u0435\\u0441\\u0441\\u0438\\u043e\\u043d\\u0430\\u043b\\u043e\\u0432, \\u0433\\u043e\\u0442\\u043e\\u0432\\u044b\\u0445 \\u043f\\u043e\\u0434\\u0434\\u0435\\u0440\\u0436\\u0430\\u0442\\u044c \\u0432\\u0430\\u0448\\u0438 \\u0438\\u043d\\u0438\\u0446\\u0438\\u0430\\u0442\\u0438\\u0432\\u044b;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043c\\u043e\\u0449\\u043d\\u043e\\u0435 \\u0436\\u0435\\u043b\\u0435\\u0437\\u043e, \\u0434\\u043e\\u043f\\u043e\\u043b\\u043d\\u0438\\u0442\\u0435\\u043b\\u044c\\u043d\\u044b\\u0435 \\u043c\\u043e\\u043d\\u0438\\u0442\\u043e\\u0440\\u044b \\u0438 \\u0432\\u0441\\u0451, \\u0447\\u0442\\u043e \\u043d\\u0443\\u0436\\u043d\\u043e \\u0434\\u043b\\u044f \\u043f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u0438\\u0432\\u043d\\u043e\\u0439 \\u0440\\u0430\\u0431\\u043e\\u0442\\u044b;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043e\\u0431\\u0443\\u0447\\u0435\\u043d\\u0438\\u0435 \\u0437\\u0430 \\u0441\\u0447\\u0451\\u0442 \\u043a\\u043e\\u043c\\u043f\\u0430\\u043d\\u0438\\u0438;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u0433\\u0438\\u0431\\u043a\\u0438\\u0439 \\u0433\\u0440\\u0430\\u0444\\u0438\\u043a</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043a\\u0440\\u0430\\u0441\\u0438\\u0432\\u044b\\u0439 \\u0438 \\u043a\\u043e\\u043c\\u0444\\u043e\\u0440\\u0442\\u043d\\u044b\\u0439 \\u043e\\u0444\\u0438\\u0441&nbsp;&nbsp;</span></span><span style=\\"font-size:10.5pt\\">\\u0433. \\u0421\\u0430\\u043d\\u043a\\u0442-\\u041f\\u0435\\u0442\\u0435\\u0440\\u0431\\u0443\\u0440\\u0433, </span><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043c. \\u041b\\u0430\\u0434\\u043e\\u0436\\u0441\\u043a\\u0430\\u044f&nbsp;&nbsp;</span></span><span style=\\"font-size:10.5pt\\">\\u043f\\u043b. \\u041a\\u0430\\u0440\\u043b\\u0430 \\u0424\\u0430\\u0431\\u0435\\u0440\\u0436\\u0435 8 \\u0412</span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u0414\\u041c\\u0421;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043f\\u0440\\u043e\\u0437\\u0440\\u0430\\u0447\\u043d\\u0430\\u044f \\u0441\\u0438\\u0441\\u0442\\u0435\\u043c\\u0430 \\u0431\\u043e\\u043d\\u0443\\u0441\\u043e\\u0432 \\u0438 \\u043f\\u0440\\u0435\\u043c\\u0438\\u0439, \\u0434\\u043e\\u0441\\u0442\\u043e\\u0439\\u043d\\u0430\\u044f \\u0437\\u0430\\u0440\\u043f\\u043b\\u0430\\u0442\\u0430 &mdash; \\u0440\\u0430\\u0437\\u043c\\u0435\\u0440 \\u043e\\u0431\\u0441\\u0443\\u0434\\u0438\\u043c \\u043d\\u0430 \\u0441\\u043e\\u0431\\u0435\\u0441\\u0435\\u0434\\u043e\\u0432\\u0430\\u043d\\u0438\\u0438.</span></span></li></ul>", "header": "<p class=\\"1\\"><span style=\\"font-size:14px\\"><strong><span style=\\"background:white\\">\\u0418\\u043d\\u0444\\u043e\\u0440\\u043c\\u0430\\u0446\\u0438\\u044f </span><span lang=\\"ru\\" style=\\"background:white\\">\\u043e \\u043f\\u0440\\u043e\\u0435\\u0 ...

# %%
{row ['vactitle'] for row in vac}
# Out:
# {'Практикант (г. Тюмень)',
#  'Senior JAVA developer (Cloud-Native Client Profile)',
#  'Клиентский менеджер /Отдел продаж лизинга крупному и среднему бизнесу/, (Екатеринбург)',
#  'Менеджер по продажам (п. Солнечный)',
#  'Разработчик SQL, Custody Self',
#  'Главный java-разработчик (трайб: Розничное взыскание)',
#  'Главный специалист(сопровождение ML моделей)',
#  'Системный аналитик (Экосистема)',
#  'Старший клиентский менеджер (Крупнейший, крупный и средний бизнес/ Управление недвижимости)',
#  'Стажер Sberseasons Кибербезопасность весна',
#  'Старший инженер/Энергетик',
#  'Старший менеджер по обслуживанию (с. Верхняя Елюзань)',
#  'Java-разработчик (АС КФЮЛ ППРБ)',
#  'инженер по сопровождению',
#  'Руководитель розничного направления дирекции интеграции продуктов экосистемы',
#  'Руководитель направления (Product менеджер)',
#  'Главный клиентский менеджер  малого бизнеса',
#  'Data Engineer (Аналитик)',
#  'Системный аналитик в команду SberUserID',
#  'Senior Системный аналитик (кредитный мониторинг)',
#  'UX-редактор сценариев',
#  'Главный инженер по разработке',
#  'Middle/Senior Java Developer (Комплаенс)',
#  'Главный инженер по тестированию (SberUser)',
#  'Solution Архитектор',
#  'Системный аналитик (система мониторинга пользовательского опыта)',
#  'Менеджер по связям с общественностью',
#  'Data scientist (Центр по исследованию данных)',
#  'Product Owner в команду «Платежи в ВСП»',
#  'Начальник отдела (call-centr)',
#  'Технолог (проекты Экосистемы)',
#  'Аналитик (Интеллектуальная система управления)',
#  'JavaScript разработчик(Backend)',
#  'Разработчик SQL (Oracle PL/SQL)',
#  'Senior Frontend-разработчик (JavaScript)',
#  'Разработчик Android-приложений (команда беспилотника)',
#  'Старший менеджер по обслуживанию (с.Крутая горка)',
#  'Менеджер по продажам (с. Кизильское)',
#  'front-end разработчик React + Redux (middle)',
#  'ИТ Лидер кластера «Каналы» (Исполнительный директор)',
#  'Старший специалист по охране труда и охране окружающей среды',
#  'Руководитель направления/Системный аналитик команды развития функционала платформы',
#  'Java разработчик (интернет-банк Сбер Бизнес для малых предпринимателей)',
#  'Системный аналитик (Pega BPM)',
#  'Координатор тестовых стендов',
#  'ABAP разработчик',
#  'Data Engineer (Middle|Senior)',
#  'Архитектор Экосистемы (Моментум)',
#  'Senior DevOps Engineer (eFX)',
#  '<p>Ведущий аналитик</p>',
#  'Devops инженер (junior)',
#  'Руководитель направления Центра организации обработки и защиты персональных данных',
#  'FrontEnd Developer',
#  'Data engineer (BigData и ML)',
#  'Системный аналитик. Сервис Автокредитование',
#  'Архитектор (Фабрика Данных)',
#  'Программист SQL',
#  'Специалист по тестированию ( QA )',
#  'Главный инженер по сопровождению Департамента Глобальных Рынков',
#  'Frontend разработчик (продукт Puzzle)',
#  'Инспектор (Отдел технических средств охраны)',
#  'Dev&Ops инженер',
#  'Инженер сопровождения',
#  'Senior Frontend разработчик (платформа виртуальных контактных центров)',
#  'Старший кредитный аналитик малого бизнеса',
#  'Специалист технической поддержки (1-ая линия',
#  'Менеджер по продажам с. Краснохолмский',
#  'Мобильный менеджер по продажам Видное',
#  'Старший менеджер по обслуживанию (с. Филатовское)',
#  'SRE-инженера (CI/CD)',
#  'Системный аналитик (проект интернет-банк СберБизнес )',
#  'Системный аналитик (платформа рекомендаций)',
#  'Стажер Sberseasons Бизнес анализ весна',
#  'Ведущий специалист по взысканию задолженности',
#  'Руководитель направления Digital Audit',
#  'Системный аналитик ( «Сегментные сервисы в CRM» )',
#  'Главный клиентский менеджер Tech Sales Регионального Государственного сектора',
#  'Тестировщик (QA engineer)',
#  'QA Automation Engineer (iOS)',
#  'Менеджер в Департамент Стратегии (IT/E-Government)',
#  'Лидер внедрения государственных суперсервисов (Руководитель проектов)',
#  'Product owner в сегмент Интернет-коммерции (E-commerce).',
#  'Ведущий менеджер по обслуживанию',
#  'Senior Java разработчик на Инвестиционную платформу юридических лиц в Сбер',
#  'Java - разработчик',
#  'Senior Developer C# (система управления Linux)',
#  'Full-Stack разработчик',
#  'Бизнес-аналитик',
#  'Java/Kotlin Developer в команду Криптосервисы',
#  'Администратор проекта/delivery-менеджер',
#  'Практикант Тула',
#  'Руководитель направления по созданию вендинговой сети',
#  'Аналитик Карта Данных',
#  'Водитель-инкассатор',
#  'QA Automation Engineer (Sber911)',
#  'Бизнес/системный аналитик',
#  'Главный дата аналитик',
#  'Клиентский менеджер по работе с крупными корпоративными клиентами',
#  'Эксперт (отдел киберкомплаенс)',
#  'Аналик SQL. Аналитик crm.Менеджер сегментации клиентской базы',
#  'Аналитик (Контактные центры)',
#  'Финансовый советник Сбербанк Первый',
#  'Главный клиентский менеджер отдела по работе с корпоративными клиентами (крупный, средний бизнес)',
#  'Ведущий инженер в департамент пользовательских решений',
#  'Инженер по тестированию  (Java, Selenium, Cucumber)',
#  'Старший менеджер по обслуживанию (с.Колташево)',
#  'Ведущий эксперт по контактным центрам',
#  'Стажер в направлении Корпоративно-инвестиционного бизнеса',
#  'Fullstack разработчик (JavaScript+Java)',
#  'Главный аналитик бизнес-процессов',
#  'Инженер по сопровождению (Экосистема)',
#  'Data Scientist БПС-Сбербанк (Минск)',
#  'Разработчик Java/Go (проект MLStorage)',
#  'Ведущий эксперт по технологиям',
#  'Главный специалист (Риски корпоративно-инвестиционного бизнеса)',
#  'Стажер Sberseasons Java весна',
#  'Системный аналитик (проект "Оценка рисков")',
#  'Руководитель направления по разработке и оптимизации управленческой отчетности Контактного Центра',
#  'Менеджер по продажам продуктов канала Управления "Безналичные решения"',
#  'Практикант, Калуга',
#  'Стажер по нагрузочному тестированию',
#  'Аналитик',
#  'Старший специалист по охране труда',
#  'Senior Data scientist (Кампании продаж)',
#  'Менеджер по обслуживанию',
#  'Специалист по разметке данных',
#  'Главный специалист /Отдел управленческой отчетности и бизнес анализа/, (Центральный офис Москва)',
#  'Территориальный менеджер управления глобальных рынков',
#  'Data Engineer SberDevices',
#  'Ведущий специалист (Управление комплаенс)',
#  'UX/UI - дизайнер',
#  'Старший клиентский менеджер (сегмент средний-крупный бизнес)',
#  'Методолог в команду «Ипотека» продукт «Новостройка»',
#  'Архитектор Data Platform РБ',
#  'Scala разработчик',
#  'Java разработчик  (СберБанк Онлайн)',
#  'DevOps инженер (ЦКМ)',
#  'Графический дизайнер',
#  'Инженер сопровождения инфраструктуры',
#  'Аналитик интеграционных взаимодействий',
#  'Менеджер по нефинансовым сервисам (продажи продуктов экосистемы Сбера корпоративным клиентам)',
#  'Эксперт VMware Workspace ONE (AirWatch)',
#  'Enterprise Aрхитектор',
#  'Data Scientist Управления внутреннего аудита',
#  'Главный инженер поддержки витринных данных( Hadoop)',
#  'Backend разработчик .NET',
#  'Бизнес-партнер по управлению персоналом',
#  'Главный специалист по телемаркетингу',
#  'Data Engineer (проект Sberbank International)',
#  'Старший менеджер по обслуживанию, с. Чарышское',
#  'Senior Power Builder Dev',
#  'Менеджер по сделкам с недвижимостью',
#  'Data - аналитик',
#  'Системный / Бизнес аналитик',
#  'Старший менеджер по обслуживанию, с.Чистоозерка',
#  'Ведущий инженер по разработке',
#  'Старший пециалист по взысканию задолженности',
#  'Менеджер по работе с клиентами малого бизнеса',
#  'Администратор тестовых стендов',
#  'Руководитель направления продаж продуктов торгового финансирования',
#  'Инженер сопровождения (ЦКМ)',
#  'Руководитель контент-группы',
#  'Python разработчик (SberDevices)',
#  'Разработчик С# (проект Portman)',
#  'Ведущий системный аналитик (Единый сервис аутентификации)',
#  'Старший менеджер по обслуживанию (п. Басьяновский)',
#  'Руководитель команды Отчетность и Аналитика',
#  'Дежурный системный администратор (ДБО ЮЛ)',
#  'Аналитик данных/Администратор проектов',
#  'Java Backend Developer',
#  'Менеджер по продажам продуктов канала',
#  'Risk Quant (Quantitative Analyst)',
#  'Java-разработчик (трайб: Розничное взыскание)',
#  'Java-разработчик (Senior / TeamLead)',
#  'Системный аналитик (проект Единое рабочее место сотрудника Операционного центра)',
#  'Senior Java-разработчик',
#  'Специалист Отдела организации сервисной поддержки',
#  'Директор по крупнейшим клиентам /Управление по работе с крупнейшими клиентами (ж/д, недвижимость)',
#  'Переводчик русского жестового языка',
#  'Ведущий инженер по автоматизации тестирования (система электронного документооборота)',
#  'Аналитик (кампании продаж)',
#  'Старший менеджер по обслуживанию (с. Дюмеево)',
#  'Ведущий инженер',
#  'Старший клиентский менеджер (Крупнейший, крупный и средний бизнес)',
#  'Старший специалист по взысканию проблемной задолженности',
#  'Руководитель проектов Agile',
#  'Бизнес-аналитик в команду «Развитие экосистемы переводов»',
#  'Java-разработчик (Jira, Confluence)',
#  'Старший инженер по сопровождению в управление ИТ `Сберегательные продукты`',
#  'Стажер / Начинающий специалист (Кибербезопасность)',
#  'Редактор портала базы данных',
#  'Клиентский менеджер малого бизнеса',
#  'Старший менеджер по обслуживанию (Венгеровский р-он, с.Вознесенка)',
#  'Java Cluster/Tech Lead Пульс',
#  'Старший инженер по сопровождению',
#  'Сценарист/ Python Junior',
#  'Ведущий специалист по работе с залогами',
#  'Java разработчик (сеньор)',
#  'Продуктовый аналитик в команду "Digital продажи в Сбербанк Онлайн"',
#  'Старший менеджер по обслуживанию (п. Юшала)',
#  'Инженер дежурной смены мониторинга ИТ-инфраструктур',
#  'Java разработчик (финансовый калькулятор)',
#  'Analyst International project in the UAE',
#  'Senior Java Developer/ Java Team Lead (Система управления знаниями и поиск)',
#  'Старший инженер по сопровождению (SberDevices)',
#  'Ведущий разработчик QlikSense',
#  'Product manager CRM. Дивизион `Массовая персонализация`',
#  'Product manager(сопровождение ML моделей)',
#  'Дежурный инженер по сопровождению',
#  'Frontend Developer (JS, React, TypeScript)',
#  'Системный аналитик/Тестировщик в команду Payments.web_СББОЛ',
#  'Ведущий системный аналитик',
#  'Психолог',
#  'Тестировщик ПО/ команда "Депозитарий"',
#  'Главный клиентский менеджер (сегмент средний-крупный бизнес)',
#  'Клиентский менеджер /Отдел продаж розничных лизинговых продуктов (банк)/, (Санкт-Петербург)',
#  'Data Engineer( GreenPlum+Hadoop)',
#  'Quality engineer',
#  'Специалист по сопровождению новых видов оборудования и внешних сетей устройств самообслуживания',
#  'QA engineer/тестировщик (команда Конструктор ставок)',
#  'JS разработчик',
#  'Водитель-инкассатор, г. Королев',
#  'Старший юрисконсульт',
#  'Backend-разработчик (mobile)',
#  'Системный аналитик(проект интернализация платежей)',
#  'Data Analyst',
#  'Участники олимпиады Я Профессионал',
#  'Java разработчик (SBI)',
#  'Разработчик Java, PL/SQL',
#  'Backend разработчик (Java/Scala)',
#  'Data engineer (Управление противодействия кибермошенничеству)',
#  'Разработчик АБС ЦФТ-Банк',
#  'Middle|Senior Java Developer (Backend)',
#  'Главный клиентский менеджерTechSales',
#  'Главный инженер в департамент ИТ `Цифровые платформы образования"',
#  'DevOps инженер Greenplum',
#  'Координатор в Штаб по HR-направлению',
#  'Эксперт по сопровождению аккредитации',
#  'Специалист по хозяйственной эксплуатации',
#  'Senior Frontend-разработчик (Сервис мониторинга разработки ПО)',
#  'JavaScript/Python developer SberDevices',
#  'Ведущий аналитик-исследователь',
#  'Специалист (Отдел технических средств охраны)',
#  'Senior/Middle Frontend разработчик в СберБизнес',
#  'Старший аналитик по созданию системы принятия решений (ИСУ) для топ-менеджеров',
#  'Старший менеджер по обслуживанию (с. Малый Ашап)',
#  'Senior Java разработчик в проект «Корпоративная аналитическая платформа»',
#  'Специалист сектора использования документов',
#  'Старший менеджер по обслуживанию с.Архиповка',
#  'Главный инженер по разработке IOS',
#  'Техническая заявка для SberDevices для Диалог',
#  'Ведущий инженер по разработке/Ведущий инженер по тестированию',
#  'Лидер Сегмента "Массовый высокодоходный сегмент"',
#  'Руководитель направления "Производственные метрики и Отчетность"',
#  'Специалист контактного центра',
#  'Frontend разработчик (React)КБ',
#  'Middle Developer C# (система управления Linux)',
#  'Team lead / Product Owner Инфоактивов (Архитектор-разработчик)',
#  'Старший менеджер по обслуживанию (с. Забитуй)',
#  'Старший менеджер по обслуживанию (п. Волово)',
#  'Java разработчик (Виртуальный Ассистент)',
#  'Мобильный менеджер по продажам Серпухов',
#  'Senior java developer (автоматизация продуктов  Сбера)',
#  'Клиентский менеджер (поставщики повторные) Волгоград',
#  'Delivery lead (Банковское сопровождение)',
#  'Инженер по тестированию',
#  'Системный аналитик в команду кастомизации мобильного приложения',
#  'UX-дизайнер навыков для виртуального помощника',
#  'Cистемный аналитик (команда Customer decisions engine)',
#  'Middle/Senior Java Developer',
#  'DEVOPS-инженер',
#  'Главный специалист по охране труда и окружающей среды, ГОиЧС',
#  'Менеджер проектов HR',
#  'Java TeamLead Автоматизированной системы "Завершение расчетов"',
#  'IOS разработчик онлайн-сервиса Экосистемы',
#  'Практика 2021',
#  'Специалист дистанционного сбора просроченной задолженности',
#  'Продакт-менеджер / Product manager',
#  'Java разработчик в команду создания единого рабочего места сотрудников Back-office',
#  'Координатор кластера',
#  'UX-райтер со знанием английского языка',
#  'Начальник центра комплексной поддержки Регионального сервисного центра',
#  'Старший менеджер по обслуживанию (Омская область, Павлоградский район, с.Южное)',
#  'Главный инженер по кибербезопасности (отдел аналитических процессов)',
#  'ITAL. Кластер POS-кредитования',
#  'QA Engineer/Аналитик СберТех',
#  'Тестировщик',
#  'Senior / Middle QA engineer (Сбербизнес)',
#  'Delivery lead Транзакционная активность кредитных карт',
#  'Инженер нагрузочного тестирования',
#  'Системный аналитик DWH',
#  'Стажер Sberseasons Право весна',
#  'Ведущий дизайнер',
#  'JAVA разработчик (РБ, Массовая персонализация)',
#  'Тестировщик (ИФТ)',
#  'Руководитель направления СББОЛ/Отдел Java разработки/, (Центральный офис Москва)',
#  'СИстемный аналитик',
#  'Практикант Рязанский ГОСБ',
#  'Методолог процесса управления технологическими инцидентами',
#  'Старший менеджер по обслуживанию (с. Пичевка)',
#  'Senior Android-developer (виртуальный ассистент-Сбербанк Онлайн)',
#  'Frontend-разработчик',
#  'Практикант, Ивановское отделение',
#  'Product Owner',
#  'Senior Java Developer (ЕРМГР)',
#  'Руководитель направления управленческой отчетности по операционному риску',
#  'Lead Data Scientist Industrial NLP',
#  'Руководитель направления портфельного менеджмента CRM и кампаний продаж',
#  'Analyst / Associate в Change подразделении Департамента Инвестиционной деятельности',
#  'QA- инженер',
#  'Старший менеджер по обслуживанию (с. Уфимский)',
#  'Product Owner (Обслуживание Госдолга)',
#  'Middle Java developer',
#  'Клиентский менеджер (банк)',
#  'Старший менеджер по обслуживанию (с. Колтовское)',
#  'Системный аналитик. Команда «POS. Gate», кластера «Покупай со Сбером»',
#  'Старший менеджер по обслуживанию (с.Ильино)',
#  'Java Team Lead (Глобальные рынки)',
#  'Инспектор',
#  'Старший менеджер по обслуживанию (с Журавка)',
#  'Тестировщик (ситуационный центр)',
#  'QA engineer в команду SberUserID',
#  'Руководитель стрима «Отчетность»',
#  'iOS-разработчик',
#  'TechLead (проект SberProfile)',
#  'Руководитель клиентско-продуктовой команды',
#  'Практикант',
#  'Клиентский менеджер /Сектор продаж розничных лизинговых продуктов (банк)/, (Самара)',
#  'Главный клиентский менеджер по привлечению и сопровождению клиентов Регионального госсектора',
#  'Java-разработчик (Залоги)',
#  'Middle Java разработчик (WEB и IOS)',
#  'Старший специалист технической поддержки',
#  'Руководитель направления (Редизайн процессов)',
#  'Scala разработчик (биометрические системы)',
#  'Мобильный менеджер по продажам с. Малояз',
#  'Руководитель направления методологии (Кибербезопасность)',
#  'Data engineer (ISAP)',
#  'Менеджер по развитию партнёров регионального государственного сектора',
#  'Прикладной системный администратор',
#  'Старший менеджер по обслуживанию (с. Шермейка)',
#  'Инженер разработчик Qlik',
#  'Старший инженер отдела информационной безопасности',
#  'Руководитель направления CDO в Дивизион "Транзакционный бизнес" (команда аналитики)',
#  'Customer journey expert',
#  'Java developer (сервисы по взаимодействию банковских и государственных структур)',
#  'Аналитик управленческой отчетности по ЮЛ',
#  'Эксперт по автоматизации тестирования',
#  'Старший экономист',
#  'Старший менеджер по обслуживанию (Новосибирская область, Ордынский р-он, с.Спирино)',
#  'Java-разработчик (HR-платформа)',
#  'Продуктовый аналитик (SberDevices)',
#  'Инженер 1 линии поддержки',
#  'Product Owner в команду по работе с госпрограммами',
#  'Старший специалист по работе с проблемными активами юридических лиц',
#  'Senior Data Scientist (knowledge mining)',
#  'Frontend-разработчик (React.js)',
#  'Трафик-менеджер',
#  'Старший менеджер по обслуживанию Тула',
#  'Senior Java developer',
#  'Дежурный администратор',
#  'Team lead команды разработки продукта (SIEM)',
#  'Администратор OpenShift',
#  'Участник конкурса студенческих ESG проектов',
#  'Помощник управляющего',
#  'Data Analyst в команду «Отчетность и аналитика»',
#  'Старший специалист по взысканию Отдела досудебного взыскания задолженности',
#  'Менеджер по продажам (пгт.Дубна)',
#  'Разработчик СУБД',
#  'Аналитик/Data Scientist (в отдел аудита)',
#  'Senior Data Engineer. Массовая персонализация',
#  'Инженер функционального тестирования',
#  'Администратор АС',
#  'Python-разработчик. Команда виртуальных ассистентов',
#  'Инженер Devops (Сайт Sberbank.ru)',
#  'Инкассатор',
#  'Java developer',
#  'Старший менеджер по обслуживанию (с.Шалинское)',
#  'Java разработчик',
#  'Старший менеджер по обучению',
#  'Специалист отдела недвижимости',
#  'Junior-Middle Data scientist',
#  'Инцидент-менеджер',
#  'Data Protection Officer (DPO)',
#  'Наставник по Python/SQL',
#  'Инженер по сопровождению (Системы расчетов)',
#  'Системный администратор VDI (DaaS)',
#  'Руководитель направления (Центр организации обработки и защиты персональных данных)',
#  'Региональный менеджер по Проблемным активам',
#  'Старший менеджер по обслуживанию,Камчатский край,  Тигильский район, с. Усть-Хайрюзово',
#  'Начальник сектора развития инфраструктуры',
#  'Java разработчик (Команда Functions)',
#  'Java разработчик (фронтальные процессы для системы Сбербанк Онлайн)',
#  'QA-инженера (команда виртуальных ассистентов)',
#  'Старший менеджер по обслуживанию (п.Казанка)',
#  'Тестировщик mobile. Массовая персонализация',
#  'Клиентский менеджер по работе с крупным бизнесом',
#  'Системный аналитик команды «Цифровая трансформация»',
#  'Ведущий специалист по поддержке сложных продуктов',
#  'Бизнес-аналитик в команду «Payments.Юпитер»',
#  'FrontEnd разработчик',
#  'Мобильный менеджер по продажам',
#  'Менеджер по оценке проектов (Дивизион "Центр корпоративных решений")',
#  'Владелец продукта',
#  'Delivery lead (ЕПК)',
#  'Golang developer',
#  'Кредитный инспектор (Крупнейший, крупный и средний бизнес /Управление недвижимости)',
#  'Администратор сопровождения (Linux)',
#  'Devops engineer',
#  'Эксперт платформы виртуализации серверов (Инженер OpenStack)',
#  'Исполнительный директор (ДомКлик)',
#  'Senior/Lead Java developer (Видеоаналитика/ VR)',
#  'Администратор Unix',
#  'Менеджер по работе с ключевыми клиентами',
#  'Аналитик по карточным продуктам',
#  'Разработчик Python',
#  'Главный DevOps инженер',
#  'Старший аналитик',
#  'Data scientist NLP/OCR/CV (команда IDP',
#  'Старший менеджер по обслуживанию (п. Пашково)',
#  'Главный системный аналитик (платформа Банка для клиентов Private banking)',
#  'Кассир кассы пересчета',
#  'Клиентский менеджер по работе с региональным госсектором',
#  'Главный инженер по разработке (проект «Внедрение МСФО17»)',
#  'Главный  java - разработчик (Управление развития технологий корпоративного взыскания)',
#  'Java разработчик корпоративной сервисной шины',
#  'Специалист контактного центра со знанием таджикского и/или узбекского языков',
#  'Старший менеджер по обслуживанию',
#  'Разработчик RPA',
#  'Методолог IT',
#  'Senior QA',
#  'Lead Data Engineer',
#  'iOS developer',
#  'Разработчик ABAP',
#  'Инженер (DevOps)',
#  'java разработчик (СберЛизинг)',
#  'QA/Ведущий инженер по тестированию (Сбербанк онлайн)',
#  'Руководитель группы Системной разработки (команда беспилотника)',
#  'Главный инженер по тестированию Управление резервами',
#  'Специалист сервисного обслуживания',
#  'DevOps Engineer (Маркетинг)',
#  'Инженер дежурной смены',
#  'Аналитик Отдела по работе с корпоративными клиентами',
#  'Стажер Sberseasons Экономика и финансы весна',
#  'Руководитель направления (Управление портфельных рисков и инструментов)',
#  'Клиентский менеджер (корпоративные клиенты)',
#  'Руководитель направления методологии (Риски)',
#  'Ведущий сетевой инженер (3-я линия поддержки)',
#  'Менеджер интеграционных проектов | SberBusiness API',
#  'Старший менеджер по продажам нефинансовых сервисов',
#  'Старший менеджер по обслуживанию (д. Аксаитово)',
#  'Java Team Lead (SberNBA)',
#  'Лидер АС (Комплаенс)',
#  'Java TeamLead',
#  'Старший юрисконсульт Отдела защиты интересов Банка в сфере Розничного бизнеса',
#  'Руководитель по кредитованию',
#  'Финансовый советник',
#  'Кладовщик',
#  'Back-end разработчик',
#  'Lead DS (RecSys) at Sberbank Corporate',
#  'Data analyst',
#  'Старший менеджер по обслуживанию (с. Тауш)',
#  'Аналитик в команду "Центр управления продаж" в канале ВСП',
#  'UX-исследователь в команду виртуального помощника',
#  'Java/Kotlin разработчик сервиса ДомКлик',
#  'Java разработчик (Медицина)',
#  'Территориальный менеджер',
#  'Инженер тестировщик',
#  'Бизнес-аналитик (проект "Государственные продукты и сервисы")',
#  'Фронтенд разработчик',
#  'Автотестировщик',
#  'Кредитный инспектор Управления мониторинга кредитных операций',
#  'Разработчик UI',
#  'Старший специалист по рассмотрению претензий на английском языке',
#  'Главный инженер по сопровождению Банковского ПО/Linux',
#  'PR менеджер SmartMarket и ассистентов Салют',
#  'Эксперт по внутренним коммуникациям',
#  'Старший менеджер по обслуживанию с. Япрынцево Переволоцкого района',
#  'Android разработчик (Private Banking)',
#  'Fullstack developer/Разработчик fullstack (Комплаенс)',
#  'Клиентский менеджер /Отдел продаж лизинга через Поставщиков 2/, (Оружейный Москва)',
#  'Руководитель направления разработки',
#  'Эксперт в области миграции данных',
#  'Lead ML-инженер (CV)',
#  'Ведущий  инженер по тестированию/НТ',
#  'Старший аудитор ( направление инвестиционного и брокерского обслуживания)',
#  "Координатор работ по  'Миграции Legacy АС на ППРБ'",
#  'Frontend-разработчик (SAPUI5)',
#  'Senior IOS-разработчик (виртуальный ассистент)',
#  'Руководитель  Java (фронтальные процессы для системы Сбербанк Онлайн)',
#  'Практикант Рязань',
#  'Аналик SQL. Менеджер сегментации клиентской базы/',
#  'Senior Data Scientist',
#  'Старший менеджер по обслуживанию (п. Кузнецовский)',
#  'DevOps Engineer / SRE',
#  'Старший менеджер по обслуживанию п. Коминтерн Кваркенского района',
#  'Адмистратор по сопровождению B2B',
#  'Разработчик Scala',
#  'ETL разработчик (Руководитель направления по аналитике данных)',
#  'QA Automation Engineer',
#  'Технический руководитель проекта. Кластер POS-кредитования',
#  'Product Owner (development and maintenance of Independent Price Verification IT System)',
#  'Начальник отдела по работе с партнерами и ипотечного кредитования',
#  'UX-исследователь',
#  'QA Engineer (Инвестор)',
#  'Старший ИТ-инженер',
#  'IT Аналитик',
#  'QA engineer (беспилотник)',
#  'Project/Account Manager в Лабораторию нейронаук и поведения человека',
#  'Senior Java- разработчик',
#  'Старший кассир',
#  'Администратор зала',
#  'Главный инженер по разработке (Frontend-разработчик)',
#  'Разработчик БД/Hadoop',
#  'Data engineer\xa0на АС Платформа КиберБезопасности',
#  'Middle/ Senior front-end Developer (Комплаенс)',
#  'Java-разработчик ( Сберкарта )',
#  'Менеджер проекта (Новые форматы размещения УС)',
#  'Ведущий менеджер по работе с клиентами МБ',
#  'Клиентский менеджер по работе с корпоративными клиентами',
#  'Разработчик front-end',
#  'Старший менеджер по обслуживанию г.Иваново',
#  'Senior/Middle Java разработчик',
#  'DevOps инженер & Linux Administrator',
#  'Системный аналитик (СИРИУС: Трансформация )',
#  'Бизнес-аналитик в команду «Классические переводы»',
#  'Бизнес-аналитик (системный аналитик)',
#  'Сервис-менеджер (Сопровождение систем в тестовом и промышленном окружении)',
#  'Стажер (Офис Agile трансформации)',
#  'Senior Java разрабочик',
#  'Senior/Middle Java Developer (Реализация SberBusiness ID)',
#  'Бизнес-аналитик (Qlik View/Sense)',
#  'Главный специалист отдела ведения проектов по проблемным активам',
#  'Главный инженер по разработке (тестировщик)',
#  'Старший инженер по разработке',
#  'Администратор SAP Basis',
#  'Инженер Golang (Platform.V.Monitor)',
#  'Главный клиентский менеджер (Крупнейший, крупный и средний бизнес)',
#  'Руководитель направления аналитики стартап-экосистемы Сбера',
#  'Клиентский менеджер СберПервый',
#  'Менеджер проекта по отраслевой экспертизе (металлургия)',
#  'Лидер «Аналитического хаба» (Дивизион "Цифровой кредитный мониторинг")',
#  'Старший менеджер по обслуживанию, с. Смоленское',
#  'Аналитик по расчетам',
#  'QA engineer SberDevices',
#  'Руководитель направления (Защита облачной инфраструктуры)',
#  'Эксперт',
#  'Ведущий Backend-разработчик (Python/Django)',
#  'Главный клиентский менеджер TechSales',
#  'Data Engineer',
#  'Специалист по охране труда',
#  'Разработчик PL/SQL, Oracle',
#  'Бизнес-аналитик ИСЖ/НСЖ',
#  'QA нагрузочное тестирование',
#  'Ведущий специалист (Управление безопасности)',
#  'Junior Devops',
#  'Менеджер проектов (Customer success manager)',
#  'Data Scientist (Управление внутреннего аудита)',
#  'QA Automation Lead',
#  'Менеджер по работе с партнерами ипотечного кредитования',
#  'Senior Brand Manager ДомКлик',
#  'Project manager в команду «Ипотека» продукт «Новостройка»',
#  'Менеджер по работе с ключевыми партнерам',
#  'QA (web тестировщик)',
#  'Ведущий системный аналитик (DWH)',
#  'Главный дизайнер мобильных приложений',
#  'Кредитный инспектор отдела мониторинга кредитных операций торговли',
#  'Менеджер по маркетингу и коммуникациям',
#  'Кредитный инспектор отдела мониторинга кредитных операций',
#  'Дежурный инженер',
#  'Региональный менеджер Управления Благосостояния',
#  'Старший разработчик / архитектор Ab Initio',
#  'Старший менеджер по обслуживанию (г. Туринск, 7003/0778)',
#  'Team Lead - в команду R&D NLP',
#  'Страший специалист по взысканию задолженности',
#  'System Analyst',
#  'Data scientist (Валидация моделей розничного бизнеса)',
#  'Senior IOS-разработчик',
#  'Руководитель направления (Дивизион "Центр Корпоративных решений")',
#  'Администратор баз данных Oracle/Oracle DBA',
#  'Senior Java Developer',
#  'Data Scientist',
#  'Data Scientist (Pricing)',
#  'Ведущий специалист Казначейства по депозитам',
#  'Менеджер по работе с ключевыми клиентами малого бизнеса Орск',
#  'Водитель-инкассатор, г.Видное',
#  'Старший менеджер по обслуживанию (с. Долговское)',
#  'Старший менеджер по обслуживанию (с.Георгиевский)',
#  'Старший менеджер по обслуживанию с. Шаповалово Акбулакский район',
#  'Директор по стратегии развития блока риски',
#  'Руководитель направления (моделирование и прогнозирование риск-метрик)',
#  'Ведущий системный аналитик (Продукт для корпоративных клиентов)',
#  'Старший менеджер по обслуживанию (с. Кукарки)',
#  'Data Scientist (Центр валидации моделей КИБ)',
#  'Специалист отдела сервисной поддержки',
#  'DevOps инженер (senior)',
#  'Python developer',
#  'Аналитик данных в команду «Голосовые сценарии. Платежи и переводы»',
#  'QA - инженер (авто + ручное)',
#  'Кредитный инспектор Управления кредитования',
#  'Ведущий специалист (отдел технических средств охраны)',
#  'Директор управления организации продаж корпоративным клиентам центра продаж корпоративным клиентам',
#  'Аналитик / data analyst. Дивизион `Лояльность`',
#  'Senior Java Developer (проект Identity & Access Management)',
#  'Кредитный аналитик эмитентов облигаций',
#  'Руководитель проектов, сегмент "Иностранцы"',
#  'Кредитный инспектор (Строительный эксперт)',
#  'Руководитель направления центра залоговой экспертизы',
#  'Middle Java developer (проект СБОЛ.Про)',
#  'Инженер по сопровождению ПО (Корпоративные клиенты)',
#  'Операционный эксперт',
#  'Senior Java разработчик  (кредитный мониторинг)',
#  'Старший менеджер по обслуживанию (с. Жуково)',
#  'QA-Engineer(Java)/ИТ-инженер СберТех',
#  'Разработчик АХД',
#  'Специалист по прямым продажам Серпухов',
#  'Главный специалист по проблемным активам крупного и среднего бизнеса',
#  'Data Analyst ("Корпоративные клиенты 360")',
#  'java разработчик. Сберегательные продукты',
#  'Системный аналитик(с\xa0функцией\xa0Delivery Lead)',
#  'Менеджер по продажам продуктов ВЭД',
#  'Senior DevOPS-инженер (Цифровые образовательные платформы)',
#  'Руководитель направления (повышение качества кредитных историй)',
#  'Эксперт по подбору персонала',
#  'java разработчик',
#  'Охранник',
#  'Тестировщик (Manual Testing)',
#  'Аналитик в команду исследования клиентской удовлетворенности',
#  'Бизнес-аналитик в команду Чаты. Мобильное Приложение',
#  'Региональный менеджер',
#  'Главный специалист поддержки продуктов/ инструментов',
#  'Системный аналитик (Data Science/Кибербезопасность)',
#  'Ведущий Java разработчик (Sber911)',
#  'Системный аналитик (ММБ)',
#  'Администратор ПРОМ',
#  'Системный аналитик Блока `Сеть продаж`',
#  'Специалист сектора внутренних коммуникаций',
#  'Начальник сектора анализа и организации кредитной работы',
#  'Тестировщик-автоматизатор (QA)',
#  'Менеджер',
#  'Менеджер по поддержке продаж массовых продуктов благосостояния',
#  'Дизайнер (договор ГПХ)',
#  'Главный специалист по администрированию кредитов',
#  'UX/UI Дизайнер',
#  'Старший клиентский менеджер',
#  'Практикант Кострома',
#  'ИТ-инженер',
#  'Старший менеджер по обслуживанию (с. Ульяново)',
#  'Ведущий инженер по сопровождению SAP HCM модуля PA/OM',
#  'Data engineer',
#  'Менеджер по продажам (аккредитивы для юридических лиц)',
#  'Стажер Sberseasons Analytics (SQL,VBA)',
#  'Старший менеджер по обслуживанию (с.Новый Мир)',
#  'Product Owner|SberBusiness',
#  'Клиентский менеджер',
#  'Консультант (Департамент инвестиционной деятельности, центр управления портфелем)',
#  'java developer. Массовая персонализация',
#  'Эксперт по кибербезопасности (расследование инцидентов)',
#  'Системный / Бизнес аналитик (проекты SberPRM)',
#  'Специалист по обработке запросов',
#  'Архитектор сервиса',
#  'React-native frontend developer (TagMe)',
#  'Водитель (персональный)',
#  'Java разработчик (ЕФС)',
#  'Исследователь данных (Data scientist)',
#  'разработчик hadoop',
#  'Senior QA Automation Engineer (Java)',
#  'Клиентский менеджер удалённых продаж',
#  'Главный инженер (Отдел розничных продуктов Департамента кибербезопасности)',
#  'Специалист по работе с внутренними клиентами (сотрудниками компании)',
#  'Старший менеджер по обслуживанию(Пензенская область, г.Белинский)',
#  'Data Analyst Дивизион `Массовая персонализация`',
#  'Ведущий инженер по кибербезопасности (Отдел управляющих процессов)',
#  'Project-менеджер на проект smart-kassa',
#  'Менеджер по продажам (с.Белозерское)',
#  'Руководитель направления (Продвижение культуры управления клиентским опытом)',
#  'Data Engineer (Spark/Hadoop) в команду маркетинговых данных и аналитики',
#  'Главный разработчик Oracle',
#  'Инженер Devops',
#  'Клиентский менеджер (сегмент средний-крупный бизнес)',
#  'Менеджер по работе с ключевыми клиентами малого бизнеса',
#  'Старший клиентский менеджер крупного и среднего бизнеса',
#  'Руководитель по внедрению проектов (экосистема)',
#  'Стажер Sberseasons JavaScript Весна',
#  'Специалист сопровождения (ИТ-договора, ЗНИ, SLA)',
#  'Специалист по прямым продажам Димитровград',
#  'Главный инженер по сопровождению в управление систем процессинга',
#  'Руководитель развития игрового направления СберСпасибо',
#  'Senior DevOps-инженер',
#  'Data Scientist в команду GraphML',
#  'Ведущий специалист по взысканию просроченной задолженности физических лиц',
#  'Строительный эксперт',
#  'QA Engineer (СберЧат)',
#  'Исследователь данных',
#  'Frontend Developer',
#  'Разработчик Oracle/Java',
#  'Data Engineer - Аналитик (Центр портфельного управления)',
#  'Product owner',
#  'Технический эксперт DaaS',
#  'Lead/Senior java developer',
#  'QA Lead автотестирование',
#  'Алгоритмист (АС Стрела)',
#  'Customer Journey Expert, сегмент «Дети, Молодежь и Родители»',
#  'Инженер сопровождения (2-я линия)',
#  'Главный инженер сектора организации сервисной поддержки',
#  'Кредитный инспектор отдела кредитования корпоративных клиентов среднего и крупного бизнеса',
#  'Начальник отдела по работе с партнерами жилищного кредитования',
#  'Data Engineer (Middle/Senior)',
#  'Senior Java разработчик (интернет-банк Сбер Бизнес для малых предпринимателей)',
#  'Стажёр Java',
#  'UX /UI дизайнер',
#  'Разработчик-Аналитик баз данных',
#  'Специалист по документообороту',
#  'Middle/Senior Data engineer (Управление торгового финансирования)',
#  'С# Разработчик',
#  'Product Owner Knowledge Assistant',
#  'Senior QA Automation Engineer (Android)',
#  'QA инженер (auto) АС ЦАРС',
#  'JAVA разработчик (микросервисы)',
#  'Senior Java Developer Sberbank Markets',
#  'Руководитель направления (CI/CD)',
#  'Региональный менеджер (сегмент РГС)',
#  'Data Scientist (Казначейство)',
#  'Senior java-разработчк',
#  'Кредитный аналитик (проектное финансирование)',
#  'Frontend (Vue.js) разработчик',
#  'Консультант SAP HCM',
#  'Архитектор DWH',
#  'Главный инженер (ручное тестирование)',
#  'Front-end разработчик (React, JS)',
#  'Технологический руководитель команды',
#  'Технический писатель (SberDevices)',
#  'Старший менеджер по обслуживанию ( с. Пудем)',
#  'QA Automation engineer/ Тестировщик-автоматизатор',
#  'QA Automation Engineer (проект Сбердруг)',
#  'Бизнес / Системный аналитик',
#  'Product Owner (Robotics)',
#  'Системный аналитик в Сбер Аналитику',
#  'Разработчик spark',
#  'Разработчик SQL (автоматизация и централизация отчетности)',
#  'Andorid-разработчик',
#  'Менеджер направления кредитования клиентов малого бизнеса',
#  'Data Scientist (персонализация в Мобильном приложении)',
#  'Data Analist',
#  'Старший менеджер по обслуживанию (п. Приполярный)',
#  'Старший менеджер по обслуживанию (Омская обл, Одесский, с Благодаровка )',
#  'Data scientist Middle/Senior в Дивизион "Особенные решения"',
#  'Стажер Sberseasons DevOps Весна',
#  'Старший специалист дистанционного сбора просроченной задолженности',
#  'Middle frontend-разработчик JS, React',
#  'Стажировка',
#  'Senior data scientist',
#  'Операционный Директор контактного центра (г. Казань)',
#  'Клиентский менеджер по работе с крупным бизнесом отрасли торговля',
#  'Старший менеджер по обслуживанию (с. Анучино)',
#  'Водитель ППКО',
#  'Pentester (Middle/Senior)',
#  'Старший инженер нагрузочного тестирования',
#  'Старший клиентский менеджер (крупнейшие клиенты)',
#  'Разработчик SQL',
#  'Кредитный специалист',
#  'Кредитный инспектор сектора финансирования недвижимости',
#  'Клиентский менеджер "Сбербанк Первый"',
#  'Java. groovy разработчик',
#  'Старший менеджер по обслуживанию с. Крючковка Беляевского района',
#  'Архитектор',
#  'QA engineer',
#  'Java Dev (SberNBA)',
#  'Разработчик GO (СберЧат)',
#  'Менеджер по управлению клиентским опытом в кластер Sbercare',
#  'Клиентский менеджер по внешнеэкономической деятельности',
#  'Главный эксперт по контактным центрам',
#  'Разработчик БД (Greenplum, Teradata)',
#  'Операционный менеджер',
#  'Бизнес _ Системный аналитик',
#  'Senior QA инженер',
#  'Дизайнер презентаций',
#  'Руководитель направления по аналитике данных',
#  'Product owner AI решений',
#  'Старший менеджер по обслуживанию (с. Наскафтым)',
#  'PostgreSQL DBA (SberITSM)',
#  'Инженер/администратор тестовых сред',
#  'Архитектор Экосистемы SberProfile',
#  'Старший менеджер по обслуживанию (п. Марковский)',
#  'Java Developer',
#  'Бизнес - аналитик',
#  'QA инженер высоконагруженной IT системы',
#  'Клиентский менеджер Сбербанк Первый',
#  'Руководитель направления ABAP',
#  'Архитектор БД (Greenplum,\xa0Teradata)',
#  'Старший клиентский менеджер отдела финансирования недвижимости',
#  'Менеджер в команду ALM DM',
#  'Аналитик-разработчик(витрины данных)',
#  'Менеджер направления развития процессов и продуктов',
#  'Специалист отдела досудебного взыскания задолженности',
#  'Менеджер по сопровождению продуктов платежных сервисов',
#  'Начальник сектора продаж розничных продуктов (управление прямых  продаж)',
#  'Python разработчик',
#  'Старший менеджер по обслуживанию (с.Верх-Ирмень)',
#  'Специалист по дистанционным продажам (без поиска клиентов)',
#  'Senior java developer (Проект: Кредитование корпоративных клиентов)',
#  "Релиз-менеджер (Дивизион 'Цифровая платформа')",
#  'Руководитель it-проектов/ Delivery Lead',
#  'Младший аналитик данных/Data Scientist',
#  'Ведущий инженер в управление серверов приложений',
#  'FullStack разработчик',
#  'Главный инженер по разработке (разработчик Java)',
#  'Менеджер по продажам',
#  'Team Lead Data Science',
#  'Кредитный инспектор по работе с юридическими лицами',
#  'Стажер Sberseasons Analytics',
#  'Аналитик по управленческой отчетности (операционные риски)',
#  'DBA платформы Teradata',
#  'Devops инженер\xa0(SberRadar)',
#  'Старший клиентский менеджер по работе с государственным сектором',
#  'Клиентский менеджер (Поставщик)',
#  'Инженер по сопровождению (дежурная смена)',
#  'Инженер-стажер',
#  'Data Engineer (Маркетинг КИБ)',
#  'Сейлз, Отдел продаж финансовым институтам фин. инструментов',
#  'UX/UI-дизайнер',
#  'Специалист архивного центра',
#  'Юрисконсульт',
#  'Аналитик со знанием SQL',
#  'Специалист по организации документооборота',
#  'Системный аналитик (Sberbank.ru)',
#  'Специалист по эксплуатации объектов недвижимости',
#  'Руководитель направления кибербезопасности (Отдел управляющих процессов)',
#  'Главный клиентский менеджер Управления организации продаж региональному государственному сектору',
#  'Customer journey expert (CJE). Бизнес аналитик в сегмент Интернет-коммерции (E-commerce).',
#  'Архитектор (Сбербизнес)',
#  'Специалист по бюджетированию и планированию в строительстве',
#  'Аналитик DWH',
#  'JAVA разработчик (Продуктовый профиль клиента)',
#  'Инженер по сопровождениюИнженер по сопровождению (АС КЮЛ ППРБ) АС',
#  'Инженер разработчик Greenplum',
#  'Java разработчик (web)',
#  'Системный аналитик (Комплаенс)',
#  'Специалист рекрутингового центра',
#  'Начальник сектора продаж клиентам малогои бизнеса',
#  'ML Engineer. Массовая персонализация',
#  'Системный аналитик/ Тестировщик Diasoft',
#  'Ведущий аналитик (команда «Платежи и Переводы»)',
#  'Java разработчик (Special solutions)',
#  'QA Lead',
#  'QA-инженер (auto) АС Калита',
#  'Старший менеджер по обслуживанию (с.Парная)',
#  'Инженер тестирования QA',
#  'Старший менеджер по обслуживанию (с.Новобирилюссы)',
#  'Frontend-разработчик (Lead)',
#  'Ведущий Java разработчик',
#  'Финансовый аналитик',
#  'Специалист по тестированию (команда развития сервисов для самозанятых)',
#  'Специалист по работе с обращениями клиентов',
#  'Старший специалист отдела внутренней отчетности (VBA, Oracle)',
#  'Аналитик SQL (кампании продаж)',
#  'Менеджер направления сервис и качество',
#  'Python backend developer (TagMe)',
#  'Android-разработчик',
#  'QA automation engineer java',
#  'Solution Architect',
#  'Middle Data Scientist в команду трайба «Эквайринг»',
#  'Java Разработчик',
#  'Количественный аналитик Инвестиционного центра',
#  'Разработка витрин в Облаке Данных(Data Engineer)',
#  'Архитектор (AI/ML)',
#  'Java-разработчик (middle)',
#  'Customer Journey Expert в команду «Ипотека» продукт «Новостройка»',
#  'HR менеджер',
#  'Помощник HR-директора',
#  'Старший менеджер по обслуживанию (с.Цолга)',
#  'Middle/Senior инженер по сопровождению',
#  'Инженер по сопровождению систем',
#  'Кредитный инспектор отдела финансирования недвижимости',
#  'Стажер Sberseasons Мобильная разработка весна',
#  'Java core',
#  'Начальник отдела',
#  'Старший менеджер по обслуживанию (ст Полетаево-1)',
#  'Главный ИТ-инженер Сбер-Тех',
#  'Middle / Senior Java Developer (SberDevices)',
#  'ETL developer',
#  'Старший менеджер по обслуживанию (Омская область, Павлоградский район, с.Новоуральское)',
#  'Data Engineer (Управление валидации)',
#  'DE ML',
#  'Старший специалист отдела мониторинга залогового обеспечения',
#  'QA Engineer (Продажа продуктов)',
#  'Старший аналитик (Хранилище данных)',
#  'Разработчик Front-end',
#  'Менеджер отдела кредитного анализа операций на финансовых рынках',
#  'Тест.  3 фев. Шуваева. iOS',
#  'Java Developer Sber Data Exchange',
#  'Аналитик в штаб блока "Розничный бизнес"',
#  'Ведущий эксперт IT инфраструктуры',
#  'Клиентский менеджер регионального госсектора',
#  'Главный специалист Отдела оформления депозитарных операций (направление корпоративные действия)',
#  'QA Automation Engineer/Ведущий инженер по автоматизации тестирования',
#  'Кредитный эксперт (кредитный мониторинг)',
#  'Разработчик web-интерфейсов (Front-end)',
#  'Ведущий эксперт по внедрению и сопровождению беспроводных сетей (Wi-Fi)',
#  'Ит-рекрутер',
#  'Java developer (middle)',
#  'Менеджер по продажам г. Троицк',
#  'Аналитик - разработчик',
#  'Data инженер / Data engineer',
#  'Middle Java Developer',
#  'Старший Devops-инженер',
#  'Лидер процесса целеполагания в блоке КИБ',
#  'Solution Architect (проект MLStorage)',
#  'Начальник отдела досудебного взыскания задолженности физических лиц',
#  'Ведущий Data Scientist (команда управления зарплатными проектами с помощью ML-моделей)',
#  'Старший менеджер по обслуживанию (д.Пронино)',
#  'UX/UI дизайнер',
#  'Data  Scientist(команда ценообразования)',
#  'Аналитик данных (аналитические витрины)',
#  'Руководитель операционной поддержки Контакт Центра',
#  'Руководитель группы VIP обслуживания',
#  'Senior Data инженер/Senior Data engineer',
#  'Аналитик (команда разработки мониторинга)',
#  'DPO (Корпоративно-инвестиционный блок)',
#  'Старший менеджер по обслуживанию (с. Рудянское)',
#  'Проект ВЭД',
#  'Старший менеджер по обслуживанию (с. Соколка)',
#  'Ст.менеджер по продаже жилищ.кредитов',
#  'Backend-разработчик (web)',
#  'Тестировщик (Функциональное тестирование)',
#  'Senior Data Scientist (Machine Learning)',
#  'енер в группу сопровождения',
#  'Аналитик ОД',
#  'Аналитик по роботизации процессов (RPA)',
#  'Эксперт Управления планирования и отчетности',
#  'Главный системный аналитик (сервисы для Private Banking)',
#  'Product Owner (виртуальный ассистент)',
#  'Главный инженер по разработке (системный аналитик)',
#  'Data engineer (ДТБ)',
#  'Специалист по функциональному тестированию',
#  'Ведущий специалист отдела учета (сопровождение торговых сделок)',
#  'Главный специалист',
#  'Product Owner (приложение "Мой бизнес")',
#  'Помощник управляющего Новосибирским  отделением',
#  'Стажер SberSeasons Java',
#  'JavaScript разработчик Сбербанк Бизнес Он-лайн',
#  'Конструктор (команда беспилотника)',
#  'Старший менеджер по нефинасовым сервисам',
#  'DevOps инженер (Linux)',
#  'Data Аналитик',
#  'Директор по маркетингу и внешним коммуникациям',
#  'Старший кредитный аналитик (сегмент малый бизнес)',
#  'Менеджер по продуктам глобальных рынков',
#  'Старший менеджер по обслуживанию (п. Комсомольский)',
#  'Системный аналитик, СберИнвестор',
#  'QA (JAVA)',
#  'DevOps engineer',
#  'Практика_Оренбург',
#  'Начальник отдела связи и мониторинга',
#  'Инженер ППРБ',
#  'Специалист отдела приема и учета документов',
#  'Системный аналитик (Sber911)',
#  'Инженер внедрения и сопровождения (проект ГосТех)',
#  'Главный клиентский менеджер',
#  'Java разработчик (Трайб Инвестиции и накопления)',
#  'Ведущий инженер (защита от DDoS-атак)',
#  'Начальник сектора недвижимости и развития инфраструктуры',
#  'Аналитик данных в команду «Инфраструктура данных»',
#  'Ведущий специалист Отдела поддержки фронт-офиса Миддл-офиса',
#  'Back-end разработчик (Java/Spring)',
#  'Midldle/Senior Frontend Developer (Сайт sberbank.ru)',
#  'Главный инженер по разработке/ Разработчик бизнес-процессов',
#  'Главный ИТ-инженер/Lead DevOps СберТех',
#  'Руководитель группы сопровождения',
#  'Руководитель направления (слияния и поглощения)',
#  'Дизайнер мобильных приложений',
#  'Web-разработчик (React)',
#  'Ведущий разработчик, Депозитарий',
#  'Системный/Процессный аналитик (автоматизация ITSM-процессов)',
#  'Юрист/Аналитик по направлению\xa0(правовые проблемы и регулирование ИИ)',
#  'Слесарь-сборщик (направление беспилотники)',
#  'Chief Data Scientist в\xa0БПС-Сбербанк (Минск)',
#  'Менеджер направления документы и процессы информационной безопасности',
#  'Team Lead Java разработки',
#  'Старший менеджер по обслуживанию (п.Новогорный)',
#  'Главный специалист по кибербезопасности (защита систем дистанционного банковского обслуживания)',
#  'Лингвист',
#  'Начальник сектора продаж розничных продуктов',
#  'Системный аналитик на хранилище данных',
#  'Администратор команды блока риски',
#  'Главный аудитор',
#  'Начальник управления по работе с партнерами и ипотечного кредитования',
#  'DevOps Python под DS',
#  'Product Owner (развитие бизнеса) E-commerce . Менеджер продукта в сегменте Интернет-коммерции.',
#  'Senior Frontend Developer (Js, React)',
#  'QA engineer авто (разработчик тестирования)',
#  'Scala - разработчик (СберЧат)',
#  'Digital-маркетолог в  (проект - юридический uber, e-commerce, legaltech)',
#  'РукНапр/EngDev/Ob-C/2ур',
#  'Java разработчик автоматизированных API-тестов',
#  'Системный аналитик в команду "Поток продаж"',
#  'Главный специалист судебного и исполнительного производства',
#  'Бизнес аналитик',
#  'Java developer (SberUser)',
#  'Главный аналитик (Проект Billing & Allocation)',
#  'Кредитный менеджер',
#  ...}

# %%
# Сколько вакансий, которые вам нравятся?
like_vac = [row for row in vac if row['vactitle']=='Главный дата аналитик']
len(like_vac)
# Out:
# 1

# %%
from collections import Counter, defaultdict

# %%
#Насколько свежие эти вакансии?
date = defaultdict(Counter)
for row in vac:
    date[row['created_at']]

# %%
max(date)
# Out:
# '2021-03-14 09:39:21.854462'

# %%
#Сколько вакансий с позициями на которых вы работаете?
my_vac = [row for row in vac if row['vactitle']=='Менеджер']
len(like_vac)
# Out:
# 1

# %%
#Сколько вакансий для аналатика данных?
DA_vac = [row for row in vac if row['vactitle']=='Аналитик данных']
len(DA_vac)
# Out:
# 5

# %%
#Сколько вакансий для аналитика данных с использованием Python?
DA_vac_ = [row for row in DA_vac if re.findall(r'Python', row['vacdescription'])]
len(DA_vac_)
# Out:
# 2
